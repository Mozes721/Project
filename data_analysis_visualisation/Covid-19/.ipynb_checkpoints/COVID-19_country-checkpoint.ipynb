# %%
import pandas as pd
import numpy as np

global_data = pd.read_csv('covid_19_series.csv')

global_data.head()
# Out:
#   Province/States    Country/Region              WHO region  1/21/2020  \
# 0       Confirmed          Globally                     NaN      282.0
# 1          Deaths          Globally                     NaN        NaN
# 2       Confirmed             China  Western Pacific Region      278.0
# 3       Confirmed  Outside of China                     NaN        4.0
# 4          Deaths             China  Western Pacific Region        NaN
#
#    1/22/2020  1/23/2020  1/24/2020  1/25/2020  1/26/2020  1/27/2020  ...  \
# 0      314.0      581.0      846.0     1320.0     2014.0     2798.0  ...
# 1        NaN        NaN        NaN        NaN        NaN        NaN  ...
# 2      309.0      571.0      830.0     1297.0     1985.0     2741.0  ...
# 3        5.0       10.0       16.0       23.0       29.0       57.0  ...
# 4        NaN        NaN        NaN        NaN        NaN       80.0  ...
#
#    5/24/2020  5/25/2020  5/26/2020  5/27/2020  5/28/2020  5/29/2020  \
# 0  5204508.0  5304772.0  5404512.0  5488825.0  5593631.0  5701337.0
# 1   337687.0   342029.0   343514.0   349095.0   353334.0   357688.0
# 2    84525.0    84536.0    84543.0    84544.0    84547.0    84547.0
# 3  5119983.0  5220236.0  5319969.0  5404281.0  5509084.0  5616790.0
# 4     4645.0     4645.0     4645.0     4645.0     4645.0     4645.0
#
#    5/30/2020  5/31/2020   6/1/2020   6/2/2020
# 0  5817385.0  5934936.0  6057853.0  6194533.0
# 1   362705.0   367166.0   371166.0   376320.0
# 2    84565.0    84570.0    84588.0    84597.0
# 3  5732820.0  5850366.0  5973265.0  6109936.0
# 4     4645.0     4645.0     4645.0     4645.0
#
# [5 rows x 137 columns]

# %%
global_data_summed = global_data.groupby('Country/Region').sum()
df = global_data_summed.drop(['WHO region'], axis=1).reset_index()
df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-f7c09d4aed9c> in <module>
#       1 global_data_summed = global_data.groupby('Country/Region').sum()
# ----> 2 df = global_data_summed.drop(['Confirmed'], axis=2).reset_index()
#       3 df.head()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3766                 raise ValueError("Cannot specify both 'labels' and "
#    3767                                  "'index'/'columns'")
# -> 3768             axis_name = self._get_axis_name(axis)
#    3769             axes = {axis_name: labels}
#    3770         elif index is not None or columns is not None:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _get_axis_name(cls, axis)
#     373                 pass
#     374         raise ValueError('No axis named {0} for object type {1}'
# --> 375                          .format(axis, type(cls)))
#     376
#     377     def _get_axis(self, axis):
#
# ValueError: No axis named 2 for object type <class 'type'>

# %%
countries_plot = ['Italy', 'Poland', 'France', 'Germany', 'United Kingdom']

start_date = '01/21/2020'
end_date = '06/02/2020'

# %%
import matplotlib.pyplot as plt
import datetime

def get_index_from_date(date_string):
    FIRST_DATE = datetime.datetime(2020, 1, 22)
    
    date_list = [int(x) for x in date_string.split('/')]
    date_object = datetime.datetime(date_list[-1], date_list[0], date_list[1])
    
    return (date_object-FIRST_DATE).days 

dates = list(global_data)[1:]

start_index = get_index_from_date(start_date)
end_index = get_index_from_date(end_date)

x_values = dates[start_index:end_index+1]


for country in
# Out:
#   File "<ipython-input-26-2e67cba8c521>", line 20
#     for country in
#                    ^
# SyntaxError: invalid syntax
